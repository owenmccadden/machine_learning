# %% [markdown]
# # Notebook to test out Google Colab

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/owenmccadden/machine_learning/blob/main/csc44800/assignment_2/google_colab.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt

list_1 = np.random.randint(0,100,100)
list_2 = np.random.randint(1,100,100)

plt.scatter(list_1, list_2)
plt.show()
